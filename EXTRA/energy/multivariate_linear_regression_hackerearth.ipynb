# %%
#MULTIVARIATE LINEAR REGRESSION

# %%
import pandas as pd
from sklearn import preprocessing
data = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/train1.csv')
data.head()
# Out:
#    1111       22.7       37.2         21         38      23.39      37.29  \
# 0  1112  21.500000  41.045000  20.500000  39.133333  22.926667  39.526667
# 1  1113  21.666667  38.000000  22.600000  35.700000  21.890000  36.590000
# 2  1114  23.290000  38.530000  21.671429  38.000000  24.290000  36.200000
# 3  1115  24.000000  42.560000  26.830000  34.356000  26.530000  40.333333
# 4  1116  18.390000  43.363333  17.700000  42.433333  19.290000  42.500000
#
#    22.83285714  34.94285714       20.5 ...       45.36   20.2  38.66333333  \
# 0         21.7    34.126667  18.633333 ...   34.663333  19.73    37.933333
# 1         22.0    35.530000  19.000000 ...   38.545000  19.79    39.430000
# 2         23.1    35.090000  22.042857 ...   38.600000  22.60    36.194286
# 3         24.5    40.900000  21.500000 ...   44.230000  22.60    44.090000
# 4         18.6    41.663333  17.200000 ...   47.600000  16.70    46.000000
#
#     12.8      760.05         62       3.5    28   5.65   70
# ...

# %%
colnames=['OBSERVATION', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'TEMP', 'PRE', 'RH_OUT', 'WS', 'V', 'TP', 'E']
data = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/train1.csv', names=colnames, header=None)
data.head()
# Out:
#    OBSERVATION         T1    RH_1         T2       RH_2         T3       RH_3  \
# 0         1111  22.700000  37.200  21.000000  38.000000  23.390000  37.290000
# 1         1112  21.500000  41.045  20.500000  39.133333  22.926667  39.526667
# 2         1113  21.666667  38.000  22.600000  35.700000  21.890000  36.590000
# 3         1114  23.290000  38.530  21.671429  38.000000  24.290000  36.200000
# 4         1115  24.000000  42.560  26.830000  34.356000  26.530000  40.333333
#
#           T4       RH_4         T5 ...        RH_8     T9       RH_9   TEMP  \
# 0  22.832857  34.942857  20.500000 ...   45.360000  20.20  38.663333  12.80
# 1  21.700000  34.126667  18.633333 ...   34.663333  19.73  37.933333   8.47
# 2  22.000000  35.530000  19.000000 ...   38.545000  19.79  39.430000  10.60
# 3  23.100000  35.090000  22.042857 ...   38.600000  22.60  36.194286  11.60
# 4  24.500000  40.900000  21.500000 ...   44.230000  22.60  44.090000  17.70
#
# ...

# %%
from sklearn import datasets, linear_model
from sklearn.linear_model import LinearRegression

# %%
X = data[['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'TEMP', 'PRE', 'RH_OUT', 'WS', 'V', 'TP']].values
Y = data[['E']].values

# %%
X = preprocessing.scale(X)
X
# Out:
# array([[ 0.63045563, -0.76890394,  0.30030269, ..., -0.22134904,
#         -0.8788032 ,  0.44847926],
#        [-0.11345087,  0.19628093,  0.07301206, ...,  1.61701811,
#         -1.0058153 , -1.35309036],
#        [-0.01013052, -0.56808524,  1.02763271, ..., -0.83413809,
#         -0.96347793, -0.32498194],
#        ...,
#        [ 0.32049459,  1.44010175,  0.43213126, ...,  0.11908932,
#          0.95581595,  1.34807413],
#        [ 1.74631537,  1.13636347,  1.6354728 , ..., -0.15326137,
#          0.89936613,  1.79311181],
#        [-0.49160333, -0.61828992, -0.29065295, ..., -0.5617874 ,
#         -1.49975122, -0.80881167]])

# %%
X.shape
# Out:
# (15780, 24)

# %%
Y
# Out:
# array([[ 70],
#        [210],
#        [ 50],
#        ...,
#        [ 50],
#        [ 60],
#        [130]], dtype=int64)

# %%
regr = linear_model.LinearRegression()
regr.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
datatest = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/test1.csv')
datatest.head()
# Out:
#    50001       21.1       39.9      19.29      41.26       21.5       40.7  \
# 0  50002  22.600000  39.030000  20.790000  40.463333  22.290000  38.290000
# 1  50003  21.000000  35.590000  19.790000  34.900000  21.166667  35.833333
# 2  50004  20.566667  37.590000  20.566667  35.700000  20.166667  37.000000
# 3  50005  21.500000  38.700000  18.566667  42.030000  22.500000  38.900000
# 4  50006  22.290000  37.126667  20.150000  39.090000  23.500000  37.790000
#
#    18.89       41.2  18.08888889    ...         47.09       18.1   44.9   2.7  \
# 0  20.29  36.700000    20.760000    ...     39.266667  19.390000  37.50  7.27
# 1  20.39  33.090000    18.000000    ...     34.126667  18.200000  39.79  6.05
# 2  22.00  35.326667    17.700000    ...     36.966667  18.000000  41.29  9.35
# 3  20.00  39.000000    19.633333    ...     45.326667  20.133333  43.20  3.03
# 4  22.70  35.000000    20.390000    ...     43.560000  20.323333  40.20  9.97
#
# ...

# %%
colnames=['OBSERVATION', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'TEMP', 'PRE', 'RH_OUT', 'WS', 'V', 'TP', 'E']
datatest = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/test1.csv', names=colnames, header=None)
datatest.head()
# Out:
#    OBSERVATION         T1   RH_1         T2       RH_2         T3       RH_3  \
# 0        50001  21.100000  39.90  19.290000  41.260000  21.500000  40.700000
# 1        50002  22.600000  39.03  20.790000  40.463333  22.290000  38.290000
# 2        50003  21.000000  35.59  19.790000  34.900000  21.166667  35.833333
# 3        50004  20.566667  37.59  20.566667  35.700000  20.166667  37.000000
# 4        50005  21.500000  38.70  18.566667  42.030000  22.500000  38.900000
#
#       T4       RH_4         T5  ...         RH_8         T9   RH_9  TEMP  \
# 0  18.89  41.200000  18.088889  ...    47.090000  18.100000  44.90  2.70
# 1  20.29  36.700000  20.760000  ...    39.266667  19.390000  37.50  7.27
# 2  20.39  33.090000  18.000000  ...    34.126667  18.200000  39.79  6.05
# 3  22.00  35.326667  17.700000  ...    36.966667  18.000000  41.29  9.35
# 4  20.00  39.000000  19.633333  ...    45.326667  20.133333  43.20  3.03
#
#           PRE     RH_OUT   WS          V    TP      E
# ...

# %%
X = datatest[['T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'TEMP', 'PRE', 'RH_OUT', 'WS', 'V', 'TP']].values

# %%
X[[3944]]
# Out:
# array([[  21.85666667,   44.66333333,   20.79      ,   43.5       ,
#           23.18222222,   44.26833333,   21.5       ,   40.56666667,
#           18.89      ,   54.33111111,    5.59      ,   76.03      ,
#           18.7       ,   35.09      ,   22.01111111,   43.26      ,
#           18.5       ,   43.645     ,    5.4       ,  762.6       ,
#           80.        ,    4.        ,   40.        ,    2.1       ]])

# %%
X = preprocessing.scale(X)
X
# Out:
# array([[-0.38204423, -0.08846296, -0.48898207, ..., -0.82474401,
#         -0.27996039, -0.31655361],
#        [ 0.56932338, -0.30805149,  0.20345903, ..., -0.82474401,
#          0.1608199 ,  0.15610215],
#        [-0.44546874, -1.17630959, -0.25816837, ...,  1.00130046,
#         -0.30839782, -1.78730475],
#        ...,
#        [-0.1283462 ,  0.0629774 , -0.57669128, ..., -0.01316869,
#          0.1608199 ,  0.18009482],
#        [-0.26153767, -0.82042473, -0.02735467, ...,  2.0157696 ,
#         -0.77761555, -0.53968551],
#        [ 0.09786788,  1.11380527,  0.20345903, ..., -0.01316869,
#          0.1608199 , -0.39572944]])

# %%
predicted_energy=[] 
for i in range (1,3945):
    print(X[[i]]) 
    energy_std = regr.predict(X[[i]])
    print("ENERGY: %.3f" %energy_std)
    predicted_energy.append(energy_std)
    i+=1
# Out:
# [[ 0.56932338 -0.30805149  0.20345903  0.0148133   0.00625613 -0.29081972
#   -0.28328217 -0.52504758  0.63677941 -0.82100276 -0.03629625 -0.30032241
#    0.11642569 -0.01381209  0.89223932 -0.70429649 -0.04265799 -0.95550076
#   -0.02633037  0.15028162  0.15128337 -0.82474401  0.1608199   0.15610215]]
# ENERGY: 98.203
# [[-0.44546874 -1.17630959 -0.25816837 -1.37385285 -0.56328863 -1.03903521
#   -0.23397974 -1.35357213 -0.87398027 -0.59991608 -0.11856279 -0.93558077
#    0.40375673 -1.71709544  0.29320626 -1.68684257 -0.64044593 -0.41247806
#   -0.25622891 -0.57643118 -1.98133975  1.00130046 -0.30839782 -1.78730475]]
# ENERGY: 149.864
# [[-0.72030827 -0.67150837  0.10036224 -1.17416449 -1.07030178 -0.68370899
#    0.55978934 -0.84023882 -1.03819328 -0.63253543  0.17266076 -0.70456801
#   -0.22358271 -0.85720667 -0.70518216 -1.14395719 -0.74091449 -0.05678634
#    0.3656278   0.42531446 -1.42596915 -1.23053167 -1.10464608 -0.54448405]]
# ENERGY: 87.812
# ...

# %%
for i in predicted_energy:
    print(i)

# %%
import numpy as np
predicted_energy=np.array([],dtype = float)
for i in range (0,3945):
    print(X[[i]]) 
    energy_std = regr.predict(X[[i]])
    print("ENERGY: %.3f" %energy_std)
    predicted_energy = np.append(predicted_energy, energy_std)
    i+=1

# %%
predicted_energy

# %%
predicted_energy.shape

# %%
np.savetxt("C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/foo.csv", predicted_energy, delimiter=",")

# %%
colnames=['OBSERVATION', 'T1', 'RH_1', 'T2', 'RH_2', 'T3', 'RH_3', 'T4', 'RH_4', 'T5', 'RH_5', 'T6', 'RH_6', 'T7', 'RH_7', 'T8', 'RH_8', 'T9', 'RH_9', 'TEMP', 'PRE', 'RH_OUT', 'WS', 'V', 'TP', 'E']
datatest = pd.read_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/test1.csv', names=colnames, header=None)
datatest.head()

# %%
datatest.to_csv('C:/Users/PRIYANSHU SHARMA/Desktop/PRIYANSHU/6 STUDY/6 SEMSTER/MACHINE LEARNING/EXTRA/energy/final2.csv', encoding='utf-8', index=False)
