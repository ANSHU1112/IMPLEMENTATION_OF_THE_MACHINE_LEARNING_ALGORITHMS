# %%
print("hello world")
# Out:
# hello world

# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
import pandas as pd

# %%
iris_data = pd.read_csv('/home/maze-runner/Downloads/uni.csv', na_values=['NA'])

# %%
iris_data.head()
print(iris_data.columns)
# Out:
# Index([u'world_rank', u'institution', u'country', u'national_rank',
#        u'quality_of_education', u'alumni_employment', u'quality_of_faculty',
#        u'publications', u'influence', u'citations', u'broad_impact',
#        u'patents', u'score', u'year'],
#       dtype='object')

# %%
import pandas as pd

iris_data = pd.read_csv('uni.csv')
iris_data.head()
# Out:
#    world_rank                            institution         country  \
# 0           1                     Harvard University             USA
# 1           2  Massachusetts Institute of Technology             USA
# 2           3                    Stanford University             USA
# 3           4                University of Cambridge  United Kingdom
# 4           5     California Institute of Technology             USA
#
#    national_rank  quality_of_education  alumni_employment  quality_of_faculty  \
# 0              1                     7                  9                   1
# 1              2                     9                 17                   3
# 2              3                    17                 11                   5
# 3              1                    10                 24                   4
# 4              4                     2                 29                   7
#
#    publications  influence  citations  broad_impact  patents   score  year
# ...

# %%
iris_data = pd.read_csv('uni.csv', na_values=['NA'])
iris_data.columns =['world_rank', 'institution', 'country', 'national_rank',
       'quality_of_education', 'alumni_employment', 'quality_of_faculty',
       'publications', 'influence', 'citations', 'broad_impact',
       'patents', 'score', 'year']

# %%
iris_data.loc[iris_data['score']>=50,'class']= 'Good'
iris_data.loc[iris_data['score']<50,'class']= 'Bad'

# %%
iris_data.head(100)
# Out:
#     world_rank                                      institution  \
# 0            1                               Harvard University
# 1            2            Massachusetts Institute of Technology
# 2            3                              Stanford University
# 3            4                          University of Cambridge
# 4            5               California Institute of Technology
# 5            6                             Princeton University
# 6            7                             University of Oxford
# 7            8                                  Yale University
# 8            9                              Columbia University
# 9           10               University of California, Berkeley
# 10          11                            University of Chicago
# 11          12                               Cornell University
# 12          13                       University of Pennsylvania
# 13          14                              University of Tokyo
# ...

# %%
iris_data.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import seaborn as sb
cols = ['alumni_employment', 'quality_of_faculty',
       'publications', 'influence', 'citations','score']

# %%
sb.pairplot(iris_data.dropna(),hue='class')

# %%
iris_data['score'].unique()
# Out:
# array([ 100.  ,   91.67,   89.5 ,   86.17,   85.21,   82.5 ,   82.34,
#          79.14,   78.86,   78.55,   73.82,   73.69,   73.64,   69.49,
#          66.94,   66.69,   65.76,   65.09,   64.05,   63.11,   61.74,
#          60.76,   60.55,   59.7 ,   59.66,   59.  ,   58.37,   57.53,
#          56.43,   56.18,   55.21,   54.43,   54.4 ,   53.72,   53.43,
#          53.09,   52.9 ,   52.64,   52.25,   52.15,   51.72,   51.66,
#          51.6 ,   51.38,   51.06,   50.68,   50.64,   50.44,   50.3 ,
#          50.29,   50.01,   49.54,   49.51,   49.1 ,   48.8 ,   48.76,
#          48.5 ,   48.44,   48.43,   48.33,   48.31,   48.26,   48.15,
#          47.94,   47.91,   47.74,   47.69,   47.68,   47.61,   47.59,
#          47.5 ,   47.31,   46.89,   46.74,   46.38,   46.34,   46.11,
#          45.82,   45.7 ,   45.47,   45.33,   45.21,   45.2 ,   45.13,
#          44.91,   44.71,   44.51,   44.44,   44.32,   44.26,   44.18,
# ...

# %%
iris_data.loc[(iris_data['score'] <= 50),'citations'].hist()

# %%
iris_data.loc[iris_data['class'] == 'Good','patents'].hist()

# %%
iris_data.loc[(iris_data['class']=='Good') & (iris_data['score'] >70) ]
# Out:
#       world_rank                                      institution  \
# 0              1                               Harvard University
# 1              2            Massachusetts Institute of Technology
# 2              3                              Stanford University
# 3              4                          University of Cambridge
# 4              5               California Institute of Technology
# 5              6                             Princeton University
# 6              7                             University of Oxford
# 7              8                                  Yale University
# 8              9                              Columbia University
# 9             10               University of California, Berkeley
# 10            11                            University of Chicago
# 11            12                               Cornell University
# 12            13                       University of Pennsylvania
# ...

# %%
iris_data.loc[iris_data['publications']>=1, 'score'].hist()

# %%
iris_data.loc[(iris_data['broad_impact'].isnull()) &
             (iris_data['national_rank']<=2)]
# Out:
#      world_rank                                      institution  \
# 0             1                               Harvard University
# 1             2            Massachusetts Institute of Technology
# 3             4                          University of Cambridge
# 6             7                             University of Oxford
# 13           14                              University of Tokyo
# 15           16  Swiss Federal Institute of Technology in Zurich
# 16           17                                 Kyoto University
# 17           18                    Weizmann Institute of Science
# 21           22                   Hebrew University of Jerusalem
# 34           35                            University of Toronto
# 40           41                                McGill University
# 47           48                          University of Paris-Sud
# 53           54                 École normale supérieure - Paris
# ...

# %%
iris_data.loc[(iris_data['class']=='Bad','influence')]
# Out:
# 51       50
# 52       68
# 53      101
# 54       74
# 55      101
# 56      101
# 57      101
# 58       35
# 59       41
# 60      101
# 61       34
# 62       53
# 63       60
# 64       93
# 65       73
# 66       38
# 67       55
# 68      101
# 69       49
# 70       32
# 71       83
# 72      101
# 73      101
# 74      101
# 75       70
# 76      101
# 77       63
# 78      100
# 79      101
# 80       37
#        ...
# 2170    887
# 2171    917
# 2172    912
# 2173    974
# 2174    778
# 2175    857
# 2176    950
# 2177    884
# 2178    984
# 2179    868
# 2180    863
# 2181    749
# 2182    991
# 2183    991
# 2184    858
# 2185    804
# 2186    855
# 2187    969
# 2188    991
# 2189    991
# 2190    974
# 2191    865
# 2192    962
# 2193    969
# 2194    430
# 2195    845
# 2196    908
# 2197    823
# 2198    974
# 2199    991
# Name: influence, Length: 1868, dtype: int64

# %%
average_petal_width=iris_data.loc[(iris_data['class']=='Bad','score')].mean()
average_petal_width
# Out:
# 45.423083511777307

# %%
iris_data.loc[(iris_data['citations']>100) &
              (iris_data['broad_impact'].isnull()), 
              'quality_of_faculty']=average_petal_width
average_petal_width
# Out:
# 45.423083511777307

# %%
iris_data.loc[(iris_data['class'] == 'Bad') &
              (iris_data['quality_of_faculty'] == average_petal_width)]
# Out:
#      world_rank                                        institution  \
# 53           54                   École normale supérieure - Paris
# 55           56                                Tel Aviv University
# 57           58                                  Dartmouth College
# 60           61                                École Polytechnique
# 64           65                               University of Geneva
# 68           69  Swiss Federal Institute of Technology in Lausanne
# 73           74                                  Nagoya University
# 76           77                        Sapienza University of Rome
# 84           85                                  Leiden University
# 90           91                                 University of Oslo
# 92           93                           University of Copenhagen
# 94           95                                   Williams College
# 96           97                           University of Nottingham
# ...

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=2,init='random',n_init=100,max_iter=30,tol=1e-04,random_state=0)
y_km = km.fit_predict(X_std)

# %%
plt.figure(figsize=(10, 10))
cols =[ 'national_rank',
       'quality_of_education', 'alumni_employment', 'quality_of_faculty',
       'publications', 'influence', 'citations','patents', 'score','class'] 
for column_index, column in enumerate(iris_data[cols].columns):
    if column == 'class':
        continue
    plt.subplot(3, 3, column_index + 1)
    sb.violinplot(x='class', y=column, data=iris_data[cols])

# %%
plt.figure(figsize=(10, 10))
for column_index, column in enumerate(iris_data[cols].columns):
    if column == 'class':
        continue
    plt.subplot(3, 3, column_index + 1)
    sb.boxplot(x='class', y=column, data=iris_data[cols])
